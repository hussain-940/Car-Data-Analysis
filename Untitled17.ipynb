# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv('/car_prices.csv', delimiter='\t')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/car_prices.csv', delimiter='\t')
plt.show()

# %%
print("Shape of the dataset:", df.shape)
print("Column names:", df.columns.tolist())
# Out:
# Shape of the dataset: (532296, 1)
# Column names: ['year,make,model,trim,body,transmission,vin,state,condition,odometer,color,interior,seller,mmr,sellingprice,saledate']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/car_prices.csv', delimiter='\t')
df[df.notnull().all(axis=1)]
# Out:
#        year,make,model,trim,body,transmission,vin,state,condition,odometer,color,interior,seller,mmr,sellingprice,saledate
# 0       2015,Kia,Sorento,LX,SUV,automatic,5xyktca69fg5...
# 1       2015,Kia,Sorento,LX,SUV,automatic,5xyktca69fg5...
# 2       2014,BMW,3 Series,328i SULEV,Sedan,automatic,w...
# 3       2015,Volvo,S60,T5,Sedan,automatic,yv1612tb4f13...
# 4       2014,BMW,6 Series Gran Coupe,650i,Sedan,automa...
# ...                                                   ...
# 532291  2015,Kia,K900,Luxury,Sedan,,knalw4d4xf6019304,...
# 532292  2012,Ram,2500,Power Wagon,Crew Cab,automatic,3...
# 532293  2012,BMW,X5,xDrive35d,SUV,automatic,5uxzw0c58c...
# 532294  2015,Nissan,Altima,2.5 S,sedan,automatic,1n4al...
# 532295  2014,Ford,F-150,XLT,SuperCrew,automatic,1ftfw1...
#
# [532296 rows x 1 columns]

# %%
import pandas as pd
data = {
    'Age': [25, 30, 45, 35, 23],
    'Salary': [50000, 60000, 80000, 75000, 48000]
}
df = pd.DataFrame(data)
print(df.describe())
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   31.600000  62600.000000
# std     8.820431  14449.913495
# min    23.000000  48000.000000
# 25%    25.000000  50000.000000
# 50%    30.000000  60000.000000
# 75%    35.000000  75000.000000
# max    45.000000  80000.000000

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', None],
    'Age': [25, 30, None, 40],
    'Salary': [50000, None, 60000, 70000]
}
df = pd.DataFrame(data)
df_clean = df.dropna()
print(df_clean)
# Out:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Alice', 'David'],
    'Age': [25, 30, 25, 40],
    'Salary': [50000, 60000, 50000, 70000]
}
df = pd.DataFrame(data)
df_unique = df.drop_duplicates()
print(df_unique)
# Out:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000
# 3  David   40   70000

# %%
import pandas as pd
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'Toyota'],
    'transmission': ['Manual', 'Automatic', 'Automatic', 'Manual']
}
df = pd.DataFrame(data)
unique_transmissions = df['transmission'].unique()
print(unique_transmissions)
# Out:
# ['Manual' 'Automatic']

# %%
import pandas as pd
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'price': [20000, 18000, 22000, 35000]
}
df = pd.DataFrame(data)
average_price = df['price'].mean()
max_price = df['price'].max()
min_price = df['price'].min()
print(f"Average Price: {average_price}")
print(f"Maximum Price: {max_price}")
print(f"Minimum Price: {min_price}")
# Out:
# Average Price: 23750.0
# Maximum Price: 35000
# Minimum Price: 18000

# %%
import pandas as pd
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'fuel_type': ['Petrol', 'Diesel', 'Petrol', 'Diesel']
}
df = pd.DataFrame(data)
most_common_fuel_type = df['fuel_type'].mode()[0]
print(f"The most common fuel type is: {most_common_fuel_type}")
# Out:
# The most common fuel type is: Diesel

# %%
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW', 'Audi'],
    'transmission': ['Manual', 'Automatic', 'Manual', 'Automatic', 'Manual']
}
df = pd.DataFrame(data)
count_per_transmission = df['transmission'].value_counts()
print(count_per_transmission)
# Out:
# transmission
# Manual       3
# Automatic    2
# Name: count, dtype: int64

# %%
import pandas as pd
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'price': [20000, 18000, 22000, 35000]
}
df = pd.DataFrame(data)
import numpy as np
price_array = df['price'].to_numpy()
print(price_array)
# Out:
# [20000 18000 22000 35000]

# %%
import numpy as np
data = np.array([3, 5, 7, 10])
mean_value = np.mean(data)
print("Mean:", mean_value)
median_value = np.median(data)
print("Median:", median_value)
std_dev = np.std(data)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 6.25
# Median: 6.0
# Standard Deviation: 2.5860201081971503

# %%
import numpy as np
import pandas as pd
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'fuel_type': ['Petrol', 'Diesel', 'Petrol', 'Diesel']
}
df = pd.DataFrame(data)
data = np.array([2, 4, 6, 8, 10])
prices = np.array([20, 25, 30, 35, 40, 45, 50])
mean_price = np.mean(prices)
above_average_count = np.sum(prices > mean_price)
print(f"Mean Price: {mean_price}")
print(f"Number of prices above the average: {above_average_count}")
# Out:
# Mean Price: 35.0
# Number of prices above the average: 3

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
plt.plot(x, y)
plt.title("line chart")
plt.xlabel("year")
plt.ylabel("price")
plt.show()

# %%
# !pip install seaborn
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/car_prices.csv", delimiter='\t')
print(df.head())
tips = sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips)
plt.show()
# Out:
#   year,make,model,trim,body,transmission,vin,state,condition,odometer,color,interior,seller,mmr,sellingprice,saledate
# 0  2015,Kia,Sorento,LX,SUV,automatic,5xyktca69fg5...
# 1  2015,Kia,Sorento,LX,SUV,automatic,5xyktca69fg5...
# 2  2014,BMW,3 Series,328i SULEV,Sedan,automatic,w...
# 3  2015,Volvo,S60,T5,Sedan,automatic,yv1612tb4f13...
# 4  2014,BMW,6 Series Gran Coupe,650i,Sedan,automa...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'owner_type': ['Owner', 'Renter', 'Owner', 'Owner', 'Renter', 'Renter', 'Owner']
}
import pandas as pd
df = pd.DataFrame(data)
sns.countplot(x='owner_type', data=df)
plt.title("Count of Owner Type")
plt.xlabel("Owner Type")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_style("darkgrid")
data = {
    'owner_type': ['Owner', 'Renter', 'Owner', 'Owner', 'Renter', 'Renter', 'Owner']
}
plt.show()

# %%
# !pip install plotly

# %%
import plotly.express as px
import pandas as pd
data = {
    'fuel_type': ['Petrol', 'Diesel', 'Electric', 'Petrol', 'Diesel', 'Petrol', 'Electric', 'Diesel', 'Petrol']
}
df = pd.DataFrame(data)
fig = px.pie(df, names='fuel_type', title="Distribution of Cars by Fuel Type")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd
data = {
    'kilometer_driven': [50000, 150000, 100000, 70000, 120000, 20000],
    'price': [5000, 3000, 4500, 5500, 4000, 6000],
    'transmission': ['Automatic', 'Manual', 'Automatic', 'Manual', 'Automatic', 'Manual']
}
df = pd.DataFrame(data)
fig = px.scatter(df, x='kilometer_driven', y='price', color='transmission',
                 title="Scatter Plot of Kilometer Driven vs Price (Colored by Transmission)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'fuel_type': ['Petrol', 'Diesel', 'Petrol', 'Diesel'],
    'price': [20000, 18000, 22000, 35000]
}
df = pd.DataFrame(data)
average_price_per_fuel = df.groupby('fuel_type')['price'].mean()
max_fuel_type = average_price_per_fuel.idxmax()
max_avg_price = average_price_per_fuel.max()
print(f"The most expensive fuel type is {max_fuel_type} with an average price of {max_avg_price:.2f}")
# Out:
# The most expensive fuel type is Diesel with an average price of 26500.00

# %%
import pandas as pd

data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'fuel_type': ['Petrol', 'Diesel', 'Petrol', 'Diesel'],
    'price': [20000, 18000, 22000, 35000]
}
df = pd.DataFrame(data)
average_price_per_fuel = df.groupby('fuel_type')['price'].mean()
max_fuel_type = average_price_per_fuel.idxmax()
max_avg_price = average_price_per_fuel.max()
print(f"The most expensive fuel type is {max_fuel_type} with an average price of {max_avg_price:.2f}")
numerical_df = df.select_dtypes(include=['number'])
correlation = numerical_df.corr(method='pearson')
print(correlation)
# Out:
# The most expensive fuel type is Diesel with an average price of 26500.00
#        price
# price    1.0

# %%
import pandas as pd

data = {
    'car': ['Toyota', 'Ford', 'Honda', 'BMW'],
    'fuel_type': ['Petrol', 'Diesel', 'Petrol', 'Diesel'],
    'price': [20000, 18000, 22000, 35000],
    'transmission': ['Manual', 'Automatic', 'Manual', 'Automatic']
}
df = pd.DataFrame(data)
price_by_year = df.groupby('transmission')['price'].mean()
print(price_by_year)
# Out:
# transmission
# Automatic    26500.0
# Manual       21000.0
# Name: price, dtype: float64

# %%
pd.DataFrame(df).to_csv('processed_car_prices.csv',index= True)
